# %%
import os
import re
import csv

def analyze_vba_file(file_path):
    with open(file_path, 'r') as file:
        content = file.read()

    result = []

    pattern = re.compile(r'(Sub|Function)\s+(\w+)\s*(\([^)]*\))?\s*(\'[^\n]*|)', re.IGNORECASE)
    for match in pattern.finditer(content):
        procedure_type, procedure_name, params, summary = match.groups()
        referenced_objects = extract_referenced_objects(content, procedure_name)

        result.append({
            'file_name': os.path.basename(file_path),
            'procedure_name': procedure_name,
            'referenced_objects': ', '.join(referenced_objects),
            'summary': summary.strip()
        })

    return result

# %%
def extract_referenced_objects(content, procedure_name):
    procedure_pattern = re.compile(r'(Sub|Function)\s+' + procedure_name + r'\s*(\([^)]*\))?\s*(\'[^\n]*|)', re.IGNORECASE)
    procedure_match = procedure_pattern.search(content)
    if not procedure_match:
        return []

    start = procedure_match.end()
    end_pattern = re.compile(r'End (Sub|Function)', re.IGNORECASE)
    end_match = end_pattern.search(content, pos=start)
    end = end_match.start()

    procedure_content = content[start:end]

    # Add regex patterns for the objects you want to extract
    object_patterns = [
        re.compile(r'Set\s+(\w+)\s*=', re.IGNORECASE),
        re.compile(r'Dim\s+(\w+)\s+As\s+(\w+)', re.IGNORECASE)
    ]

    objects = set()
    for pattern in object_patterns:
        for match in pattern.finditer(procedure_content):
            objects.add(match.group(1))

    return list(objects)

# %%
folder_path = "C:\\Users\\kmurph59\\Documents\\GitHub\\hello-world\\Aha VBA"
output_csv = "VBA_MetaData.csv"

result = []

for file_name in os.listdir(folder_path):
    print(file_name)
    if file_name.endswith(".bas") or file_name.endswith(".frm"):
        file_path = os.path.join(folder_path, file_name)
        result.extend(analyze_vba_file(file_path))

with open(output_csv, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['file_name', 'procedure_name', 'referenced_objects', 'summary']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    for row in result:
        
        writer.writerow(row)
# Out:
# frmComment.frm
# frmComment.frx
# frmNewTask.frm
# frmNewTask.frx
# frm_Event.frm
# frm_Event.frx
# JsonConverter.bas
# mdl_Aha.bas
# mdl_environ.bas
# mdl_EventCreate.bas
# {'file_name': 'frmComment.frm', 'procedure_name': 'Frame1_Click', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'frmComment.frm', 'procedure_name': 'Private', 'referenced_objects': 'sBody, sTask', 'summary': ''}
# {'file_name': 'frmComment.frm', 'procedure_name': 'UserForm_Initialize', 'referenced_objects': 'sBody, sTask', 'summary': ''}
# {'file_name': 'frmComment.frm', 'procedure_name': 'Private', 'referenced_objects': 'sBody, sTask', 'summary': ''}
# {'file_name': 'frmComment.frm', 'procedure_name': 'cmdComment_Click', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'frmNewTask.frm', 'procedure_name': 'cbo_Assigned_Change', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'frmNewTask.frm', 'procedure_name': 'Private', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'frmNewTask.frm', 'procedure_name': 'cbo_ProjectStatus_Change', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'frmNewTask.frm', 'procedure_name': 'Private', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'frmNewTask.frm', 'procedure_name': 'cmd_CreateTask_Click', 'referenced_objects': 'Result, sBody, sSubject', 'summary': "' also creates event"}
# {'file_name': 'frmNewTask.frm', 'procedure_name': 'Private', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'frmNewTask.frm', 'procedure_name': 'cmd_refresh_Click', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'frmNewTask.frm', 'procedure_name': 'Private', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'frmNewTask.frm', 'procedure_name': 'Frame1_Click', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'frmNewTask.frm', 'procedure_name': 'Private', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'frmNewTask.frm', 'procedure_name': 'lst_Projects_Click', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'frmNewTask.frm', 'procedure_name': 'Private', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'frmNewTask.frm', 'procedure_name': 'lst_Projects_DblClick', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'frmNewTask.frm', 'procedure_name': 'Private', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'frmNewTask.frm', 'procedure_name': 'UserForm_Initialize', 'referenced_objects': 'CurrentUser', 'summary': ''}
# {'file_name': 'frmNewTask.frm', 'procedure_name': 'Function', 'referenced_objects': 'workspace, enteam_preferred_delivery_due_date, enteam_expected_benefit, UserFullName, mandatorydiscretionary_need, enteam_support_type, oHTTP, ReleaseNum, enteam_request_type, enteam_priority, value_stream_ets, epic_reference_num, enteam_type, sURL, sBody', 'summary': ''}
# {'file_name': 'frmNewTask.frm', 'procedure_name': 'Function', 'referenced_objects': 'workspace, enteam_preferred_delivery_due_date, enteam_expected_benefit, UserFullName, mandatorydiscretionary_need, enteam_support_type, oHTTP, ReleaseNum, enteam_request_type, enteam_priority, value_stream_ets, epic_reference_num, enteam_type, sURL, sBody', 'summary': ''}
# {'file_name': 'frmNewTask.frm', 'procedure_name': 'Function', 'referenced_objects': 'workspace, enteam_preferred_delivery_due_date, enteam_expected_benefit, UserFullName, mandatorydiscretionary_need, enteam_support_type, oHTTP, ReleaseNum, enteam_request_type, enteam_priority, value_stream_ets, epic_reference_num, enteam_type, sURL, sBody', 'summary': ''}
# {'file_name': 'frmNewTask.frm', 'procedure_name': 'Function', 'referenced_objects': 'workspace, enteam_preferred_delivery_due_date, enteam_expected_benefit, UserFullName, mandatorydiscretionary_need, enteam_support_type, oHTTP, ReleaseNum, enteam_request_type, enteam_priority, value_stream_ets, epic_reference_num, enteam_type, sURL, sBody', 'summary': ''}
# {'file_name': 'frm_Event.frm', 'procedure_name': 'UserForm_Click', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'frm_Event.frm', 'procedure_name': 'Private', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'frm_Event.frm', 'procedure_name': 'UserForm_Initialize', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'utc_popen', 'referenced_objects': 'ParseJson, json_Index', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'utc_pclose', 'referenced_objects': 'ParseJson, json_Index', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'utc_fread', 'referenced_objects': 'ParseJson, json_Index', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'utc_feof', 'referenced_objects': 'ParseJson, json_Index', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'utc_popen', 'referenced_objects': 'ParseJson, json_Index', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'utc_pclose', 'referenced_objects': 'ParseJson, json_Index', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'utc_fread', 'referenced_objects': 'ParseJson, json_Index', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'utc_feof', 'referenced_objects': 'ParseJson, json_Index', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'utc_GetTimeZoneInformation', 'referenced_objects': 'ParseJson, json_Index', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'utc_SystemTimeToTzSpecificLocalTime', 'referenced_objects': 'ParseJson, json_Index', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'utc_TzSpecificLocalTimeToSystemTime', 'referenced_objects': 'ParseJson, json_Index', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'utc_GetTimeZoneInformation', 'referenced_objects': 'ParseJson, json_Index', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'utc_SystemTimeToTzSpecificLocalTime', 'referenced_objects': 'ParseJson, json_Index', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'utc_TzSpecificLocalTimeToSystemTime', 'referenced_objects': 'ParseJson, json_Index', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'ParseJson', 'referenced_objects': 'ParseJson, json_Index', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'ConvertToJson', 'referenced_objects': 'json_Value, json_Buffer, json_Index, json_LBound, json_BufferLength, json_LBound2D, json_DateStr, json_Key, json_BufferPosition, json_UBound, json_IsFirstItem, json_InnerIndentation, json_SkipItem, json_Index2D, json_Indentation, json_IsFirstItem2D, json_PrettyPrint, json_Converted, json_UBound2D', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'json_ParseObject', 'referenced_objects': 'json_NextChar, json_ParseObject, json_Key', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'ElseIf', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'Private', 'referenced_objects': 'json_ParseArray', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'json_ParseArray', 'referenced_objects': 'json_ParseArray', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'ElseIf', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'Private', 'referenced_objects': 'json_ParseArray', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'json_ParseValue', 'referenced_objects': 'json_ParseValue', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'Private', 'referenced_objects': 'json_ParseArray', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'json_ParseString', 'referenced_objects': 'json_Char, json_Buffer, json_BufferPosition, json_BufferLength, json_Code, json_Quote', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'Case', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'Private', 'referenced_objects': 'json_ParseArray', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'json_ParseNumber', 'referenced_objects': 'json_Value, json_Char, json_IsLargeNumber', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'End', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'Private', 'referenced_objects': 'json_ParseArray', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'json_ParseKey', 'referenced_objects': 'json_Char', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'Private', 'referenced_objects': 'json_ParseArray', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'json_IsUndefined', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'Private', 'referenced_objects': 'json_ParseArray', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'json_Encode', 'referenced_objects': 'json_Char, json_Buffer, json_Index, json_BufferPosition, json_BufferLength, json_AscCode', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'Private', 'referenced_objects': 'json_ParseArray', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'json_Peek', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'Private', 'referenced_objects': 'json_ParseArray', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'json_SkipSpaces', 'referenced_objects': '', 'summary': "' Increment index to skip over spaces"}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'Private', 'referenced_objects': 'json_ParseArray', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'json_StringIsLargeNumber', 'referenced_objects': 'json_CharCode, json_CharIndex, json_Length', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'End', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'Private', 'referenced_objects': 'json_ParseArray', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'json_ParseErrorMessage', 'referenced_objects': 'json_StopIndex, json_StartIndex', 'summary': "' Provide detailed parse error message, including details of where and what occurred"}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'Private', 'referenced_objects': 'json_ParseArray', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'json_BufferAppend', 'referenced_objects': 'json_AppendLength, json_LengthPlusPosition, json_AddedLength', 'summary': "' VBA can be slow to append strings due to allocating a new string for each append"}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'call', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'Private', 'referenced_objects': 'json_ParseArray', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'json_BufferToString', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'ParseUtc', 'referenced_objects': 'utc_LocalDate, utc_TimeZoneInfo', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'utc_ErrorHandling', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'ConvertToUtc', 'referenced_objects': 'utc_UtcDate, utc_TimeZoneInfo', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'utc_ErrorHandling', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'ParseIso', 'referenced_objects': 'utc_Offset, utc_HasOffset, utc_OffsetIndex, utc_NegativeOffset', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'utc_ErrorHandling', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'ConvertToIso', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'utc_ErrorHandling', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'utc_ConvertDate', 'referenced_objects': 'utc_ShellCommand, utc_Result', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'Private', 'referenced_objects': 'json_ParseArray', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'utc_ExecuteInShell', 'referenced_objects': 'utc_Chunk, utc_Read, utc_File', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'Do', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'utc_DateToSystemTime', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'Private', 'referenced_objects': 'json_ParseArray', 'summary': ''}
# {'file_name': 'JsonConverter.bas', 'procedure_name': 'utc_SystemTimeToDate', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'mdl_Aha.bas', 'procedure_name': 'CreateEvent', 'referenced_objects': 'myFrm', 'summary': ''}
# {'file_name': 'mdl_Aha.bas', 'procedure_name': 'Sub', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'mdl_Aha.bas', 'procedure_name': 'Sub', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'mdl_Aha.bas', 'procedure_name': 'Function', 'referenced_objects': 'sSubject, olMail, objAppointment, objMeeting, objItem', 'summary': ''}
# {'file_name': 'mdl_Aha.bas', 'procedure_name': 'Function', 'referenced_objects': 'sSubject, olMail, objAppointment, objMeeting, objItem', 'summary': ''}
# {'file_name': 'mdl_Aha.bas', 'procedure_name': 'Sub', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'mdl_Aha.bas', 'procedure_name': 'Function', 'referenced_objects': 'sSubject, olMail, objAppointment, objMeeting, objItem', 'summary': ''}
# {'file_name': 'mdl_Aha.bas', 'procedure_name': 'Function', 'referenced_objects': 'sSubject, olMail, objAppointment, objMeeting, objItem', 'summary': ''}
# {'file_name': 'mdl_Aha.bas', 'procedure_name': 'Function', 'referenced_objects': 'sSubject, olMail, objAppointment, objMeeting, objItem', 'summary': ''}
# {'file_name': 'mdl_Aha.bas', 'procedure_name': 'Function', 'referenced_objects': 'sSubject, olMail, objAppointment, objMeeting, objItem', 'summary': ''}
# {'file_name': 'mdl_Aha.bas', 'procedure_name': 'Function', 'referenced_objects': 'sSubject, olMail, objAppointment, objMeeting, objItem', 'summary': ''}
# {'file_name': 'mdl_Aha.bas', 'procedure_name': 'Function', 'referenced_objects': 'sSubject, olMail, objAppointment, objMeeting, objItem', 'summary': ''}
# {'file_name': 'mdl_Aha.bas', 'procedure_name': 'Function', 'referenced_objects': 'sSubject, olMail, objAppointment, objMeeting, objItem', 'summary': ''}
# {'file_name': 'mdl_Aha.bas', 'procedure_name': 'Sub', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'mdl_Aha.bas', 'procedure_name': 'Sub', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'mdl_Aha.bas', 'procedure_name': 'Sub', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'mdl_Aha.bas', 'procedure_name': 'Function', 'referenced_objects': 'sSubject, olMail, objAppointment, objMeeting, objItem', 'summary': ''}
# {'file_name': 'mdl_Aha.bas', 'procedure_name': 'Function', 'referenced_objects': 'sSubject, olMail, objAppointment, objMeeting, objItem', 'summary': ''}
# {'file_name': 'mdl_Aha.bas', 'procedure_name': 'Sub', 'referenced_objects': '', 'summary': ''}
# {'file_name': 'mdl_environ.bas', 'procedure_name': 'SetEnvironmentVariable', 'referenced_objects': 'ret', 'summary': ''}
# {'file_name': 'mdl_environ.bas', 'procedure_name': 'mySetEnvironmentVariable', 'referenced_objects': 'ret', 'summary': ''}
# {'file_name': 'mdl_EventCreate.bas', 'procedure_name': 'SendHTTPEvent', 'referenced_objects': 'EventObject, workspace, UserFullName, oHTTP, sURL, sBody', 'summary': ''}
# {'file_name': 'mdl_EventCreate.bas', 'procedure_name': 'Function', 'referenced_objects': 'http, url, jsonObj, GetRecord, cleanedJson', 'summary': ''}
# {'file_name': 'mdl_EventCreate.bas', 'procedure_name': 'Function', 'referenced_objects': 'http, url, jsonObj, GetRecord, cleanedJson', 'summary': ''}
# {'file_name': 'mdl_EventCreate.bas', 'procedure_name': 'Function', 'referenced_objects': 'http, url, jsonObj, GetRecord, cleanedJson', 'summary': ''}
# {'file_name': 'mdl_EventCreate.bas', 'procedure_name': 'Function', 'referenced_objects': 'http, url, jsonObj, GetRecord, cleanedJson', 'summary': ''}
# {'file_name': 'mdl_EventCreate.bas', 'procedure_name': 'CleanJson', 'referenced_objects': 'regex', 'summary': ''}
# {'file_name': 'mdl_EventCreate.bas', 'procedure_name': 'Function', 'referenced_objects': 'http, url, jsonObj, GetRecord, cleanedJson', 'summary': ''}
# {'file_name': 'mdl_EventCreate.bas', 'procedure_name': 'Dim', 'referenced_objects': 'sSubject, oHTTP, jsonObj, jsonData, GetObject, sURL, sBody, jsonStr', 'summary': ''}
# {'file_name': 'mdl_EventCreate.bas', 'procedure_name': 'GetObject', 'referenced_objects': 'sSubject, oHTTP, jsonObj, GetObject, sURL, sBody, jsonStr', 'summary': ''}
# {'file_name': 'mdl_EventCreate.bas', 'procedure_name': 'UpdateObject', 'referenced_objects': 'url, http', 'summary': ''}

# %%
print(os.path.join(folder_path, file_name))
# Out:
# C:\Users\kmurph59\Documents\GitHub\hello-world\Aha VBA\mdl_EventCreate.bas

# %%
with open(os.path.join(folder_path, file_name), 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['file_name', 'procedure_name', 'referenced_objects', 'summary']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
